# %%
import pandas as pd

# %%
df=pd.read_csv('vgsales.csv')

# %%
df.head()
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %%
df.isnull().count()
# Out:
# Rank            16598
# Name            16598
# Platform        16598
# Year            16598
# Genre           16598
# Publisher       16598
# NA_Sales        16598
# EU_Sales        16598
# JP_Sales        16598
# Other_Sales     16598
# Global_Sales    16598
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16598 entries, 0 to 16597
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rank          16598 non-null  int64
#  1   Name          16598 non-null  object
#  2   Platform      16598 non-null  object
#  3   Year          16327 non-null  float64
#  4   Genre         16598 non-null  object
#  5   Publisher     16540 non-null  object
#  6   NA_Sales      16598 non-null  float64
#  7   EU_Sales      16598 non-null  float64
#  8   JP_Sales      16598 non-null  float64
#  9   Other_Sales   16598 non-null  float64
#  10  Global_Sales  16598 non-null  float64
# dtypes: float64(6), int64(1), object(4)
# memory usage: 1.4+ MB

# %%
safe_data=df

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16598 entries, 0 to 16597
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rank          16598 non-null  int64
#  1   Name          16598 non-null  object
#  2   Platform      16598 non-null  object
#  3   Year          16327 non-null  float64
#  4   Genre         16598 non-null  object
#  5   Publisher     16540 non-null  object
#  6   NA_Sales      16598 non-null  float64
#  7   EU_Sales      16598 non-null  float64
#  8   JP_Sales      16598 non-null  float64
#  9   Other_Sales   16598 non-null  float64
#  10  Global_Sales  16598 non-null  float64
# dtypes: float64(6), int64(1), object(4)
# memory usage: 1.4+ MB

# %%
df[df['Year'].isna()==False]['Year']
# Out:
# 0        2006.0
# 1        1985.0
# 2        2008.0
# 3        2009.0
# 4        1996.0
#           ...
# 16593    2002.0
# 16594    2003.0
# 16595    2008.0
# 16596    2010.0
# 16597    2003.0
# Name: Year, Length: 16327, dtype: float64

# %%
df['Year'].unique()
# Out:
# array([2006., 1985., 2008., 2009., 1996., 1989., 1984., 2005., 1999.,
#        2007., 2010., 2013., 2004., 1990., 1988., 2002., 2001., 2011.,
#        1998., 2015., 2012., 2014., 1992., 1997., 1993., 1994., 1982.,
#        2003., 1986., 2000.,   nan, 1995., 2016., 1991., 1981., 1987.,
#        1980., 1983., 2020., 2017.])

# %%
df.dropna(subset=['Year'],inplace=True)

# %%
df['Year'].unique()
# Out:
# array([2006., 1985., 2008., 2009., 1996., 1989., 1984., 2005., 1999.,
#        2007., 2010., 2013., 2004., 1990., 1988., 2002., 2001., 2011.,
#        1998., 2015., 2012., 2014., 1992., 1997., 1993., 1994., 1982.,
#        2003., 1986., 2000., 1995., 2016., 1991., 1981., 1987., 1980.,
#        1983., 2020., 2017.])

# %%
df['Publisher']=df['Publisher'].fillna('UNKNOWN')

# %%
df[df['Platform'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Rank, Name, Platform, Year, Genre, Publisher, NA_Sales, EU_Sales, JP_Sales, Other_Sales, Global_Sales]
# Index: []

# %%
df.head()
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %%
for i in df['Platform'].unique():
    print(f'{i} : {df[df['Platform']==i]['Platform'].count()}')
# Out:
# Wii : 1290
# NES : 98
# GB : 97
# DS : 2133
# X360 : 1235
# PS3 : 1304
# PS2 : 2127
# SNES : 239
# GBA : 811
# 3DS : 500
# PS4 : 336
# N64 : 316
# PS : 1189
# XB : 803
# PC : 943
# 2600 : 116
# PSP : 1197
# XOne : 213
# GC : 542
# WiiU : 143
# GEN : 27
# DC : 52
# PSV : 412
# SAT : 173
# SCD : 6
# WS : 6
# NG : 12
# TG16 : 2
# 3DO : 3
# GG : 1
# PCFX : 1

# %%
df.head()
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 16327 entries, 0 to 16597
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rank          16327 non-null  int64
#  1   Name          16327 non-null  object
#  2   Platform      16327 non-null  object
#  3   Year          16327 non-null  float64
#  4   Genre         16327 non-null  object
#  5   Publisher     16327 non-null  object
#  6   NA_Sales      16327 non-null  float64
#  7   EU_Sales      16327 non-null  float64
#  8   JP_Sales      16327 non-null  float64
#  9   Other_Sales   16327 non-null  float64
#  10  Global_Sales  16327 non-null  float64
# dtypes: float64(6), int64(1), object(4)
# memory usage: 1.5+ MB

# %%
df['MEAN_SALES']=df['Global_Sales']/4

# %%
df.head()
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  MEAN_SALES
# 0     41.49     29.02      3.77         8.46         82.74     20.6850
# 1     29.08      3.58      6.81         0.77         40.24     10.0600
# 2     15.85     12.88      3.79         3.31         35.82      8.9550
# 3     15.75     11.01      3.28         2.96         33.00      8.2500
# 4     11.27      8.89     10.22         1.00         31.37      7.8425

# %%
df['Year']=df['Year'].astype('int64')

# %%
df['Year'].dtype
# Out:
# dtype('int64')

# %%
df['Year'].unique()
# Out:
# array([2006, 1985, 2008, 2009, 1996, 1989, 1984, 2005, 1999, 2007, 2010,
#        2013, 2004, 1990, 1988, 2002, 2001, 2011, 1998, 2015, 2012, 2014,
#        1992, 1997, 1993, 1994, 1982, 2003, 1986, 2000, 1995, 2016, 1991,
#        1981, 1987, 1980, 1983, 2020, 2017])

# %%
for i in df['Year'].unique():
    print(f'{i} : {df[df['Year']==i]['Global_Sales'].sum().round(2)}')
# Out:
# 2006 : 521.04
# 1985 : 53.94
# 2008 : 678.9
# 2009 : 667.3
# 1996 : 199.15
# 1989 : 73.45
# 1984 : 50.36
# 2005 : 459.94
# 1999 : 251.27
# 2007 : 611.13
# 2010 : 600.45
# 2013 : 368.11
# 2004 : 419.31
# 1990 : 49.39
# 1988 : 47.22
# 2002 : 395.52
# 2001 : 331.47
# 2011 : 515.99
# 1998 : 256.47
# 2015 : 264.44
# 2012 : 363.54
# 2014 : 337.05
# 1992 : 76.16
# 1997 : 200.98
# 1993 : 45.98
# 1994 : 79.17
# 1982 : 28.86
# 2003 : 357.85
# 1986 : 37.07
# 2000 : 201.56
# 1995 : 88.11
# 2016 : 70.93
# 1991 : 32.23
# 1981 : 35.77
# 1987 : 21.74
# 1980 : 11.38
# 1983 : 16.79
# 2020 : 0.29
# 2017 : 0.05

# %%
df.head()
# Out:
#    Rank                      Name Platform  Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  MEAN_SALES
# 0     41.49     29.02      3.77         8.46         82.74     20.6850
# 1     29.08      3.58      6.81         0.77         40.24     10.0600
# 2     15.85     12.88      3.79         3.31         35.82      8.9550
# 3     15.75     11.01      3.28         2.96         33.00      8.2500
# 4     11.27      8.89     10.22         1.00         31.37      7.8425

# %%
df.to_csv('Cleaned_Data.csv',index=False)

# %%
cleandf=pd.read_csv('Cleaned_Data.csv')

# %%
cleandf.head()
# Out:
#    Rank                      Name Platform  Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  MEAN_SALES
# 0     41.49     29.02      3.77         8.46         82.74     20.6850
# 1     29.08      3.58      6.81         0.77         40.24     10.0600
# 2     15.85     12.88      3.79         3.31         35.82      8.9550
# 3     15.75     11.01      3.28         2.96         33.00      8.2500
# 4     11.27      8.89     10.22         1.00         31.37      7.8425
